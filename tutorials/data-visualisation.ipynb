# %% [markdown]
# # Data Visualisation

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
apple_data <- read_csv("../data/apple_mobility_data.csv")
# Out:
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   .default = col_double(),
#   geo_type = col_character(),
#   region = col_character(),
#   transportation_type = col_character(),
#   alternative_name = col_character(),
#   `sub-region` = col_character(),
#   country = col_character(),
#   `2020-05-11` = col_logical(),
#   `2020-05-12` = col_logical()
# )
# ℹ Use `spec()` for the full column specifications.

# %%
head(apple_data)
# Out:
#   geo_type       region    transportation_type alternative_name sub-region
# 1 country/region Albania   driving             NA               NA
# 2 country/region Albania   walking             NA               NA
# 3 country/region Argentina driving             NA               NA
# 4 country/region Argentina walking             NA               NA
# 5 country/region Australia driving             AU               NA
# 6 country/region Australia transit             AU               NA
#   country 2020-01-13 2020-01-14 2020-01-15 2020-01-16 ⋯ 2020-08-11 2020-08-12
# 1 NA      100         95.30     101.43      97.20     ⋯ 215.44     216.40
# 2 NA      100        100.68      98.93      98.46     ⋯ 166.27     168.27
# 3 NA      100         97.07     102.45     111.21     ⋯  57.49      59.57
# 4 NA      100         95.11     101.37     112.67     ⋯  45.29      46.27
# 5 NA      100        102.98     104.21     108.63     ⋯  85.36      89.13
# 6 NA      100        101.78     100.64      99.58     ⋯  39.96      41.42
#   2020-08-13 2020-08-14 2020-08-15 2020-08-16 2020-08-17 2020-08-18 2020-08-19
# 1 232.93     248.51     267.54     255.43     229.61     216.43     209.82
# 2 161.58     165.29     181.54     143.41     165.42     162.47     150.15
# 3  60.74      71.67      71.08      43.32      42.59      53.91      56.11
# 4  47.79      55.35      52.62      33.36      36.19      44.18      42.19
# 5  95.89      93.84      79.57      81.30      83.35      85.40      87.96
# 6  41.61      42.73      36.14      39.14      40.17      40.45      40.91
#   2020-08-20
# 1 228.91
# 2 166.82
# 3  58.64
# 4  44.98
# 5  93.81
# 6  42.32

# %%
long_apple_data <- gather(apple_data, key=day, value=mobility_data, `2020-01-13`:`2020-08-20`)

head(long_apple_data)
# Out:
#   geo_type       region    transportation_type alternative_name sub-region
# 1 country/region Albania   driving             NA               NA
# 2 country/region Albania   walking             NA               NA
# 3 country/region Argentina driving             NA               NA
# 4 country/region Argentina walking             NA               NA
# 5 country/region Australia driving             AU               NA
# 6 country/region Australia transit             AU               NA
#   country day        mobility_data
# 1 NA      2020-01-13 100
# 2 NA      2020-01-13 100
# 3 NA      2020-01-13 100
# 4 NA      2020-01-13 100
# 5 NA      2020-01-13 100
# 6 NA      2020-01-13 100

# %%
country_avg <- long_apple_data %>%
                filter(transportation_type == "walking") %>%
                group_by(country) %>%
                summarise(walking_avg = mean(mobility_data, na.rm = TRUE)) %>%
                filter(!is.na(country))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)

# %%
country_avg
# Out:
#    country              walking_avg
# 1  Argentina             45.58114
# 2  Australia             74.74141
# 3  Austria               82.25767
# 4  Belgium               95.08492
# 5  Brazil                70.09204
# 6  Canada               104.44288
# 7  Chile                 43.93895
# 8  Denmark               96.25475
# 9  Egypt                 75.25982
# 10 Finland              101.24032
# 11 France                93.73389
# 12 Germany               97.82288
# 13 Greece                79.84781
# 14 India                 61.15394
# 15 Indonesia             64.62626
# 16 Ireland               71.07644
# 17 Israel                78.58292
# 18 Italy                 67.03955
# 19 Japan                111.47079
# 20 Malaysia              54.75489
# 21 Mexico                83.09946
# 22 Morocco               68.37311
# 23 Netherlands          101.64100
# 24 New Zealand           74.05352
# 25 Norway               102.24872
# 26 Philippines           54.12680
# 27 Poland                89.91749
# 28 Portugal              70.91068
# 29 Republic of Korea     51.42689
# 30 Romania               73.63265
# 31 Russia                99.92307
# 32 Saudi Arabia          82.25397
# 33 South Africa          67.29685
# 34 Spain                 64.34703
# 35 Sweden               101.57196
# 36 Switzerland           90.19106
# 37 Taiwan               117.47589
# 38 Thailand              54.70192
# 39 Turkey                80.81930
# 40 United Arab Emirates  68.98941
# 41 United Kingdom        84.97754
# 42 United States        112.34410
# 43 Vietnam               84.75532

# %%
ggplot(country_avg, aes(y = reorder(country, walking_avg), weight = walking_avg)) + 
    xlab("Relative rate of walking distance request") +
    ylab("Country") +
    theme_minimal() +
    geom_bar(fill = "blue")
# Out:
# plot without title

# %%
library(lubridate)

long_apple_data$day <- as_date(long_apple_data$day)
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
italy_spain_data <- long_apple_data %>%
                filter(country == c("Italy", "Spain"), transportation_type == "walking") %>%
                group_by(country, day) %>%
                summarise(walking_avg = mean(mobility_data, na.rm = TRUE))
# Out:
# Warning message in country == c("Italy", "Spain"):
# “longer object length is not a multiple of shorter object length”
# `summarise()` regrouping output by 'country' (override with `.groups` argument)

# %%
ggplot(italy_spain_data, aes(x = day, 
                             y = walking_avg, 
                             group = country, 
                             colour = country)) +
    geom_line() + 
    theme_bw() +
    ylab("Relative Volume of Walking Direction Requests") +
    facet_wrap(~ country) # ~ means explained by.
# Out:
# plot without title
