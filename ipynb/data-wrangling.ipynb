# %% [markdown]
# # Data "Wrangling"
#
# If you haven't already; `install.package('tidyverse')`

# %%
# Im
library(tidyverse)

load("../data/apple_mobility_data.Rdata")
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Show the first 6 rows of the list
head(apple_data)
# Out:
#   geo_type       region    transportation_type alternative_name sub-region
# 1 country/region Albania   driving             NA               NA
# 2 country/region Albania   walking             NA               NA
# 3 country/region Argentina driving             NA               NA
# 4 country/region Argentina walking             NA               NA
# 5 country/region Australia driving             AU               NA
# 6 country/region Australia transit             AU               NA
#   country 2020-01-13 2020-01-14 2020-01-15 2020-01-16 ⋯ 2020-08-11 2020-08-12
# 1 NA      100         95.30     101.43      97.20     ⋯ 215.44     216.40
# 2 NA      100        100.68      98.93      98.46     ⋯ 166.27     168.27
# 3 NA      100         97.07     102.45     111.21     ⋯  57.49      59.57
# 4 NA      100         95.11     101.37     112.67     ⋯  45.29      46.27
# 5 NA      100        102.98     104.21     108.63     ⋯  85.36      89.13
# 6 NA      100        101.78     100.64      99.58     ⋯  39.96      41.42
#   2020-08-13 2020-08-14 2020-08-15 2020-08-16 2020-08-17 2020-08-18 2020-08-19
# 1 232.93     248.51     267.54     255.43     229.61     216.43     209.82
# 2 161.58     165.29     181.54     143.41     165.42     162.47     150.15
# 3  60.74      71.67      71.08      43.32      42.59      53.91      56.11
# 4  47.79      55.35      52.62      33.36      36.19      44.18      42.19
# 5  95.89      93.84      79.57      81.30      83.35      85.40      87.96
# 6  41.61      42.73      36.14      39.14      40.17      40.45      40.91
#   2020-08-20
# 1 228.91
# 2 166.82
# 3  58.64
# 4  44.98
# 5  93.81
# 6  42.32

# %%
# Subsetting the dataset (dplyr)
# Create a new list where only Brazil is included.
brazil_data <- filter(apple_data, region == "Brazil")

regions <- select(apple_data, region)

# %%
# Creates a tibble
transport_types <- count(apple_data, transportation_type)

alpha_order <- arrange(apple_data, region)

# %%
# Transform the dataset from a "wide" set to a "long" set.
long_apple_data <- gather(apple_data, key=day, value=mobility_data, `2020-01-13`:`2020-08-20`)

# %%
# To find the minimum 'mobility' one can either;
min(long_apple_data$mobility_data, na.rm = TRUE)
# Out:
# [1] 2.43

# %%
# Or, to follow the tutorial more closely;
arrange(long_apple_data, mobility_data)
# Out:
#        geo_type   region                    transportation_type
# 1      city       Seville                   walking
# 2      city       Seville                   walking
# 3      city       Seville                   walking
# 4      city       Seville                   walking
# 5      city       Florence                  walking
# 6      city       Seville                   walking
# 7      city       Florence                  walking
# 8      city       Florence                  walking
# 9      city       Florence                  walking
# 10     city       Florence                  walking
# 11     city       Florence                  walking
# 12     city       Florence                  walking
# 13     city       Florence                  walking
# 14     city       Florence                  walking
# 15     sub-region West Coast Region         driving
# 16     city       Seville                   walking
# 17     city       Florence                  walking
# 18     city       Florence                  walking
# 19     city       Florence                  walking
# 20     city       Florence                  walking
# 21     city       Barcelona                 walking
# 22     city       Florence                  walking
# 23     city       Florence                  walking
# 24     city       Florence                  walking
# 25     sub-region West Coast Region         driving
# 26     city       Florence                  walking
# 27     city       Florence                  walking
# 28     city       Seville                   walking
# 29     city       Seville                   walking
# 30     city       Seville                   walking
# ⋮      ⋮          ⋮                         ⋮
# 801096 sub-region Canton of Uri             driving
# 801097 sub-region Carlow                    driving
# 801098 sub-region Cavan                     driving
# 801099 sub-region Central Ostrobothnia      driving
# 801100 sub-region Ceuta                     driving
# 801101 sub-region Gotland County            driving
# 801102 sub-region Isle of Man               driving
# 801103 sub-region Kainuu                    driving
# 801104 sub-region Leitrim                   driving
# 801105 sub-region Longford                  driving
# 801106 sub-region Melilla                   driving
# 801107 sub-region Monaghan                  driving
# 801108 sub-region Mukdahan Province         driving
# 801109 sub-region Nakhon Phanom Province    driving
# 801110 sub-region Narathiwat Province       driving
# 801111 sub-region Nong Bua Lam Phu Province driving
# 801112 sub-region Nunavut                   driving
# 801113 sub-region Nógrád County             driving
# 801114 sub-region Offaly                    driving
# 801115 sub-region Pattani Province          driving
# 801116 sub-region Phatthalung Province      driving
# 801117 sub-region Phayao Province           driving
# 801118 sub-region Ranong Province           driving
# 801119 sub-region Satun Province            driving
# 801120 sub-region Sukhothai Province        driving
# 801121 sub-region Taoyuan City              driving
# 801122 sub-region Uthai Thani Province      driving
# 801123 sub-region Uttaradit Province        driving
# 801124 sub-region Yala Province             driving
# 801125 sub-region Yasothon Province         driving
#        alternative_name                     sub-region     country
# 1      Sevilla                              Andalusia      Spain
# 2      Sevilla                              Andalusia      Spain
# 3      Sevilla                              Andalusia      Spain
# 4      Sevilla                              Andalusia      Spain
# 5      Firenze                              Tuscany Region Italy
# 6      Sevilla                              Andalusia      Spain
# 7      Firenze                              Tuscany Region Italy
# 8      Firenze                              Tuscany Region Italy
# 9      Firenze                              Tuscany Region Italy
# 10     Firenze                              Tuscany Region Italy
# 11     Firenze                              Tuscany Region Italy
# 12     Firenze                              Tuscany Region Italy
# 13     Firenze                              Tuscany Region Italy
# 14     Firenze                              Tuscany Region Italy
# 15     NA                                   NA             New Zealand
# 16     Sevilla                              Andalusia      Spain
# 17     Firenze                              Tuscany Region Italy
# 18     Firenze                              Tuscany Region Italy
# 19     Firenze                              Tuscany Region Italy
# 20     Firenze                              Tuscany Region Italy
# 21     NA                                   Catalonia      Spain
# 22     Firenze                              Tuscany Region Italy
# 23     Firenze                              Tuscany Region Italy
# 24     Firenze                              Tuscany Region Italy
# 25     NA                                   NA             New Zealand
# 26     Firenze                              Tuscany Region Italy
# 27     Firenze                              Tuscany Region Italy
# 28     Sevilla                              Andalusia      Spain
# 29     Sevilla                              Andalusia      Spain
# 30     Sevilla                              Andalusia      Spain
# ⋮      ⋮                                    ⋮              ⋮
# 801096 Kanton Uri|Canton d'Uri              NA             Switzerland
# 801097 NA                                   NA             Ireland
# 801098 NA                                   NA             Ireland
# 801099 Keski-Pohjanmaa                      NA             Finland
# 801100 NA                                   NA             Spain
# 801101 NA                                   NA             Sweden
# 801102 NA                                   NA             United Kingdom
# 801103 NA                                   NA             Finland
# 801104 NA                                   NA             Ireland
# 801105 NA                                   NA             Ireland
# 801106 NA                                   NA             Spain
# 801107 NA                                   NA             Ireland
# 801108 มุกดาหาร|จังหวัดมุกดาหาร|จ.มุกดาหาร       NA             Thailand
# 801109 นครพนม|จังหวัดนครพนม|จ.นครพนม          NA             Thailand
# 801110 นราธิวาส|จังหวัดนราธิวาส|จ.นราธิวาส       NA             Thailand
# 801111 หนองบัวลำภู|จังหวัดหนองบัวลำภู|จ.หนองบัวลำภู NA             Thailand
# 801112 NU                                   NA             Canada
# 801113 Nógrád megye                         NA             Hungary
# 801114 NA                                   NA             Ireland
# 801115 ปัตตานี|จังหวัดปัตตานี|จ.ปัตตานี             NA             Thailand
# 801116 พัทลุง|จังหวัดพัทลุง|จ.พัทลุง                NA             Thailand
# 801117 พะเยา|จังหวัดพะเยา|จ.พะเยา             NA             Thailand
# 801118 ระนอง|จังหวัดระนอง|จ.ระนอง             NA             Thailand
# 801119 สตูล|จังหวัดสตูล|จ.สตูล                   NA             Thailand
# 801120 สุโขทัย|จังหวัดสุโขทัย|จ.สุโขทัย             NA             Thailand
# 801121 桃園市                               NA             Taiwan
# 801122 อุทัยธานี|จังหวัดอุทัยธานี|จ.อุทัยธานี          NA             Thailand
# 801123 อุตรดิตถ์|จังหวัดอุตรดิตถ์|จ.อุตรดิตถ์          NA             Thailand
# 801124 ยะลา|จังหวัดยะลา|จ.ยะลา                NA             Thailand
# 801125 ยโสธร|จังหวัดยโสธร|จ.ยโสธร             NA             Thailand
#        day        mobility_data
# 1      2020-03-21 2.43
# 2      2020-03-29 2.54
# 3      2020-03-22 2.86
# 4      2020-04-12 2.86
# 5      2020-04-12 2.95
# 6      2020-03-28 3.05
# 7      2020-04-13 3.19
# 8      2020-03-25 3.22
# 9      2020-03-22 3.32
# 10     2020-03-26 3.37
# 11     2020-03-31 3.39
# 12     2020-04-05 3.47
# 13     2020-03-27 3.50
# 14     2020-04-01 3.53
# 15     2020-03-27 3.59
# 16     2020-04-19 3.65
# 17     2020-03-29 3.68
# 18     2020-03-23 3.71
# 19     2020-04-19 3.72
# 20     2020-04-04 3.78
# 21     2020-04-05 3.78
# 22     2020-03-28 3.81
# 23     2020-04-02 3.88
# 24     2020-04-03 3.89
# 25     2020-03-28 3.94
# 26     2020-03-24 3.95
# 27     2020-04-06 3.95
# 28     2020-04-10 3.95
# 29     2020-04-11 3.95
# 30     2020-04-04 3.97
# ⋮      ⋮          ⋮
# 801096 2020-08-20 NA
# 801097 2020-08-20 NA
# 801098 2020-08-20 NA
# 801099 2020-08-20 NA
# 801100 2020-08-20 NA
# 801101 2020-08-20 NA
# 801102 2020-08-20 NA
# 801103 2020-08-20 NA
# 801104 2020-08-20 NA
# 801105 2020-08-20 NA
# 801106 2020-08-20 NA
# 801107 2020-08-20 NA
# 801108 2020-08-20 NA
# 801109 2020-08-20 NA
# 801110 2020-08-20 NA
# 801111 2020-08-20 NA
# 801112 2020-08-20 NA
# 801113 2020-08-20 NA
# 801114 2020-08-20 NA
# 801115 2020-08-20 NA
# 801116 2020-08-20 NA
# 801117 2020-08-20 NA
# 801118 2020-08-20 NA
# 801119 2020-08-20 NA
# 801120 2020-08-20 NA
# 801121 2020-08-20 NA
# 801122 2020-08-20 NA
# 801123 2020-08-20 NA
# 801124 2020-08-20 NA
# 801125 2020-08-20 NA
